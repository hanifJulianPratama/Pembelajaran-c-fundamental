# %% [markdown]
# <a href="https://colab.research.google.com/github/hanifJulianPratama/Pembelajaran-c-fundamental/blob/main/learn1%20python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Pertemuan pertama pembelajaran bahasa pythob

# %%
a=2
b=3
c=a+b
print (c)
# Out:
# 5
